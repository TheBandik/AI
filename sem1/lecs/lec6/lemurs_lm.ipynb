# %% [markdown]
# # Лемуры

# %% [markdown]
# ## Данные

# %% [markdown]
# ### Виды лемуров
#
# | №   | Таксон | Латинское название           | Русское название          |
# | --- | ------ | ---------------------------- | ------------------------- |
# | 1   | CMED   | Cheirogaleus medius          | Толстохвостый лемур       |
# | 2   | DMAD   | Daubentonia madagascariensis | Мадагаскарская руконожка  |
# | 3   | EALB   | Eulemur albifrons            | Белолобый лемур           |
# | 4   | ECOL   | Eulemur collaris             | Красноошейниковый лемур   |
# | 5   | ECOR   | Eulemur coronatus            | Венценосный лемур         |
# | 6   | EFLA   | Eulemur flavifrons           | Голубоглазый лемур        |
# | 7   | EFUL   | Eulemur fulvus               | Бурый лемур               |
# | 8   | EMAC   | Eulemur macaco               | Чёрный лемур              |
# | 9   | EMON   | Eulemur mongoz               | Мангустовый лемур         |
# | 10  | ERUB   | Eulemur rubriventer          | Рыжебрюхий лемур          |
# | 11  | ERUF   | Eulemur rufus                | Краснолобый лемур         |
# | 12  | ESAN   | Eulemur sanfordi             | Лемур Санфорда            |
# | 13  | EUL    | Eulemur                      | Обыкновенный лемур        |
# | 14  | GMOH   | Galago moholi                | Южный галаго              |
# | 15  | HGG    | Hapalemur griseus griseus    | Серый лемур               |
# | 16  | LCAT   | Lemur catta                  | Кошачий лемур             |
# | 17  | LTAR   | Loris tardigradus            | Красный тонкий лори       |
# | 18  | MMUR   | Mircocebus murinus           | Серый мышиный лемур       |
# | 19  | MZAZ   | Mirza coquereli              | Карликовый лемур Кокерела |
# | 20  | NCOU   | Nycticebus coucang           | Медленный лори            |
# | 21  | NPYG   | Nycticebus pygmaeus          | Малый лори                |
# | 22  | OGG    | Otolemur garnettii garnettii | Галаго Гарнетта           |
# | 23  | PCOQ   | Propithecus coquereli        | Сифака Кокереля           |
# | 24  | PPOT   | Perodicticus potto           | Обыкновенные потто        |
# | 25  | VAR    | Varecia                      | Гибрид Вари               |
# | 26  | VRUB   | Varecia rubra                | Рыжий вари                |
# | 27  | VVV    | Varecia variegata variegata  | Лемур вари                |

# %% [markdown]
# ### Переменные
#
# | №   | Переменная                | Описание                                                                                                                                                                   |
# | --- | ------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | 1   | Taxon                     | Таксономический код: в большинстве случаев состоит из первой буквы рода и первых трёх букв вида                                                                            |
# | 2   | Hybrid                    | Статус гибрида: N - не гибрид, S - видовой гибрид, B - подвидовой гибрид                                                                                                   |
# | 3   | DLC_ID                    | Идентификатор: уникальный номер особи в DLC                                                                                                                                |
# | 4   | Sex                       | Пол: M - самец, F - самка                                                                                                                                                  |
# | 5   | Name                      | Имя особи при DLC                                                                                                                                                          |
# | 6   | DOB                       | Дата рождения: указывается точно, если нет записи в поле Estimated_DOB                                                                                                     |
# | 7   | Estimated_DOB             | Предполагаемая дата рождения: Y - приближено к году, M - приближено к месяцу, D - приближено к дню. U - неизвестно. Если поле пустое, значит точная дата рождения известна |
# | 8   | Weight_g                  | Вес (в граммах)                                                                                                                                                            |
# | 9   | Weight_Date               | Дата измерения веса                                                                                                                                                        |
# | 10  | MonthOfWeight             | Месяц измерения веса                                                                                                                                                       |
# | 11  | AgeAtWt_d                 | Возраст в днях                                                                                                                                                             |
# | 12  | AgeAtWt_wk                | Возраст в неделях                                                                                                                                                          |
# | 13  | AgeAtWt_mo                | Возраст в месяцах                                                                                                                                                          |
# | 14  | AgeAtWt_mo_NoDec          | Возраст в месяцах целый                                                                                                                                                    |
# | 15  | AgeAtWt_y                 | Возраст в годах                                                                                                                                                            |
# | 16  | Days_Since_PrevWt         | Разница в количестве дней между прошлым измерением веса и текущим                                                                                                          |
# | 17  | Change_Since_PrevWt _g    | Разница в граммах между прошлым измерением веса и текущим                                                                                                                  |
# | 18  | Avg_Daily_WtChange_g      | Среднесуточное изменение в весе, в граммах, между прошлым измерением веса и текущим                                                                                        |
# | 19  | DOD                       | Дата смерти                                                                                                                                                                |
# | 20  | DaysBeforeDeath           | Количество дней с момента, когда было последнее измерение веса, до смерти особи                                                                                            |
# | 21  | Birth_Type                | Тип рождения: CB - в неволе, WB - в дикой природе,  UNK - неизвестно                                                                                                       |
# | 22  | Birth_Institution         | Учереждение рождения: указывается ISIS аббривиатура учереждения, где животное родилось. Если рождено в дикой природе, то указывается страна рождения                       |
# | 23  | Litter_Size               | Размер помёта: количество детёнышей в помёте, в котором было рождено текущее животное. Указывается только для животных, рождённых в DLC                                    |
# | 24  | R_Min_Dam_AgeAtConcep_y   | Минимальный возраст матери на момент зачатия                                                                                                                               |
# | 25  | Age_Category              | Категория возраста                                                                                                                                                         |
# | 26  | Current_Resident          | Живёт ли текущее животное на данный момент в DLC                                                                                                                           |
# | 27  | Preg_Status               | Статус беременности: P - беремена, NP - не беремена (включая самцов)                                                                                                       |
# | 28  | Expected_Gestation_d      | Ожидаемая продолжительность беременности в днях                                                                                                                            |
# | 29  | ConcepDate_IfPreg         | Дата зачатия, если самка на момент измерения веса беремена                                                                                                                 |
# | 30  | InfantDOB_IfPreg          | Дата рождения детёныша у самки                                                                                                                                             |
# | 31  | DaysBeforeInfBirth_IfPreg | Количество дней до родов                                                                                                                                                   |
# | 32  | Pct_PregRemain_IfPreg     | Процент остаточной беременности                                                                                                                                            |
# | 33  | InfantLitSz_IfPreg        | Размер помёта, рождённого самкой                                                                                                                                           |

# %% [markdown]
# ## Анализ

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import mean_absolute_percentage_error

from patsy import dmatrices
from statsmodels.stats.stattools import durbin_watson

import matplotlib.pyplot as plt

# %% [markdown]
# ### Задача

# %% [markdown]
# Найти факторы среди представленных данных, которые влияют на вес лемуров

# %% [markdown]
# ### Загрузка данных

# %%
df = pd.read_csv('lemurs_weights.csv', sep=',', encoding = "ISO-8859-1")
df
# Out:
#       Taxon Hybrid  DLC_ID Sex       Name        DOB DOB_Estimated  Weight_g  \
# 0       OGG      N       5   M      KANGA  25Aug1961           NaN    1086.0
# 1       OGG      N       5   M      KANGA  25Aug1961           NaN    1190.0
# 2       OGG      N       6   F        ROO  17Mar1961           NaN     947.0
# 3       OGG      N       6   F        ROO  17Mar1961           NaN    1174.0
# 4       OGG      N       9   M  POOH BEAR  30Sep1963           NaN     899.0
# ...     ...    ...     ...  ..        ...        ...           ...       ...
# 82604  NCOU      N     996   F     DANU-A  30May1984           NaN      38.0
# 82605  NCOU      N     998   M     KANTIL  17Nov1976           NaN    1079.0
# 82606  NCOU      N     998   M     KANTIL  17Nov1976           NaN    1003.0
# 82607  NCOU      N     998   M     KANTIL  17Nov1976           NaN     902.0
# 82608  NCOU      N     998   M     KANTIL  17Nov1976           NaN     806.0
#
# ...

# %% [markdown]
# ### Предварительная обработка данных

# %%
black_list = [
    'Hybrid',
    'Name',
    'DLC_ID',
    'DOB',
    'DOB_Estimated',
    'Weight_Date',
    'AgeAtWt_d',
    'AgeAtWt_wk',
    'AgeAtWt_mo',
    'AgeAtWt_mo_NoDec',
    'Change_Since_PrevWt_g',
    'Days_Since_PrevWt',
    'Avg_Daily_WtChange_g',
    'DOD',
    'DaysBeforeDeath',
    'Litter_Size',
    'R_Min_Dam_AgeAtConcep_y',
    'Age_Category',
    'Current_Resident',
    'Expected_Gestation_d',
    'ConcepDate_IfPreg',
    'InfantDOB_IfPreg',
    'DaysBeforeInfBirth_IfPreg',
    'Pct_PregRemain_IfPreg',
    'InfantLitSz_IfPreg'
]

tab = df.drop(black_list, axis=1)
tab
# Out:
#       Taxon Sex  Weight_g  MonthOfWeight  AgeAtWt_y Birth_Type  \
# 0       OGG   M    1086.0              2      10.48         CB
# 1       OGG   M    1190.0              6      10.83         CB
# 2       OGG   F     947.0              2      10.93         CB
# 3       OGG   F    1174.0              6      11.28         CB
# 4       OGG   M     899.0              2       8.39         CB
# ...     ...  ..       ...            ...        ...        ...
# 82604  NCOU   F      38.0              5       0.00         CB
# 82605  NCOU   M    1079.0             10       7.94         CB
# 82606  NCOU   M    1003.0             12       8.09         CB
# 82607  NCOU   M     902.0              4       8.42         CB
# 82608  NCOU   M     806.0              6       8.58         CB
#
#        Birth_Institution Preg_Status
# 0      Duke Lemur Center          NP
# 1      Duke Lemur Center          NP
# 2      Duke Lemur Center          NP
# 3      Duke Lemur Center          NP
# ...

# %%
df['Sex'].value_counts()
# Out:
# M     42037
# F     40557
# ND       15
# Name: Sex, dtype: int64

# %%
df['Taxon'].value_counts()
# Out:
# MMUR    12275
# PCOQ     8996
# CMED     8070
# LCAT     7490
# DMAD     5077
# VRUB     4166
# EMON     3645
# EFLA     3217
# NPYG     2757
# VVV      2735
# ECOL     2467
# NCOU     2367
# MZAZ     2266
# HGG      2119
# ECOR     2094
# LTAR     1946
# EMAC     1734
# EUL      1583
# ERUF     1538
# ERUB     1356
# OGG      1122
# GMOH      937
# ESAN      798
# PPOT      665
# VAR       534
# EFUL      328
# EALB      327
# Name: Taxon, dtype: int64

# %%
taxon = pd.factorize(tab['Taxon'])[0]
sex = pd.factorize(tab['Sex'])[0]
birth_type = pd.factorize(tab['Birth_Type'])[0]
birth_institution = pd.factorize(tab['Birth_Institution'])[0]
preg_status = pd.factorize(tab['Preg_Status'])[0]

data = {
    'Taxon': taxon,
    'Sex': sex,
    'Weight': df['Weight_g'],
    'Month': df['MonthOfWeight'],
    'Age': df['AgeAtWt_y'],
    'Birth_Type': birth_type,
    'Birth_Institution': birth_institution,
    'Preg_Status': preg_status
}

# %%
pd.factorize(tab['Taxon'])
# Out:
# (array([ 0,  0,  0, ..., 13, 13, 13], dtype=int64),
#  Index(['OGG', 'EMON', 'HGG', 'VVV', 'EUL', 'ERUF', 'EFUL', 'VAR', 'LCAT',
#         'EMAC', 'PCOQ', 'CMED', 'MMUR', 'NCOU', 'LTAR', 'NPYG', 'GMOH', 'MZAZ',
#         'ECOL', 'EALB', 'VRUB', 'ECOR', 'ESAN', 'ERUB', 'EFLA', 'DMAD', 'PPOT'],
#        dtype='object'))

# %%
new_df = pd.DataFrame(data)
new_df = new_df.dropna()
# new_df = new_df[:100]
new_df
# Out:
#        Taxon  Sex  Weight  Month    Age  Birth_Type  Birth_Institution  \
# 0          0    0  1086.0      2  10.48           0                  0
# 1          0    0  1190.0      6  10.83           0                  0
# 2          0    1   947.0      2  10.93           0                  0
# 3          0    1  1174.0      6  11.28           0                  0
# 4          0    0   899.0      2   8.39           0                  0
# ...      ...  ...     ...    ...    ...         ...                ...
# 82604     13    1    38.0      5   0.00           0                  0
# 82605     13    0  1079.0     10   7.94           0                 87
# 82606     13    0  1003.0     12   8.09           0                 87
# 82607     13    0   902.0      4   8.42           0                 87
# 82608     13    0   806.0      6   8.58           0                 87
#
#        Preg_Status
# 0                0
# 1                0
# 2                0
# 3                0
# ...

# %% [markdown]
# ### Модель множественной регрессии

# %%
result = smf.ols(formula="Weight ~ C(Sex) + C(Taxon) + C(Month) + Age + C(Birth_Type) + C(Birth_Institution) + C(Preg_Status)", data=new_df).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.753
# Method:                 Least Squares   F-statistic:                     1936.
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):               0.00
# Time:                        19:26:12   Log-Likelihood:            -6.5252e+05
# No. Observations:               82601   AIC:                         1.305e+06
# Df Residuals:                   82470   BIC:                         1.307e+06
# Df Model:                         130
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    692.1967     22.168     31.226      0.000     648.749     735.645
# ...

# %%
plot = new_df.loc[new_df['Age'] > 10]
plot = plot.loc[plot['Taxon'] == 3]

print(sns.lmplot(x='Age', y='Weight', data=plot))

# %%
print(sns.lmplot(x='Age', y='Weight', data=new_df))

# %% [markdown]
# ### Исследование модели на мультиколлинеарность

# %% [markdown]
# #### Матрица парных коэффициентов корреляции

# %%
cor = new_df.corr()
cor
# Out:
#                       Taxon       Sex    Weight     Month       Age  \
# Taxon              1.000000  0.020389  0.068326 -0.001724  0.060796
# Sex                0.020389  1.000000  0.025252 -0.005683  0.007150
# Weight             0.068326  0.025252  1.000000  0.022571  0.333741
# Month             -0.001724 -0.005683  0.022571  1.000000  0.007165
# Age                0.060796  0.007150  0.333741  0.007165  1.000000
# Birth_Type         0.235944  0.023055  0.132617 -0.007741  0.312353
# Birth_Institution -0.009741  0.005485 -0.091457  0.008553  0.097764
# Preg_Status        0.003200  0.156744  0.112692 -0.026149 -0.002665
#
#                    Birth_Type  Birth_Institution  Preg_Status
# Taxon                0.235944          -0.009741     0.003200
# Sex                  0.023055           0.005485     0.156744
# Weight               0.132617          -0.091457     0.112692
# Month               -0.007741           0.008553    -0.026149
# ...

# %%
from statsmodels.graphics.correlation import plot_corr

fig=plot_corr(cor, xnames=cor.columns)

# %% [markdown]
# #### Детерминант матрицы корреляции

# %%
det = np.linalg.det(cor)
print(f'Детерминант: {round(det, 2)}')
# Out:
# Детерминант: 0.68

# %% [markdown]
# #### Коэффициенты вздутия дисперсии

# %%
def vif(bl):
    tab = new_df.drop(bl, axis=1)
    features = "+".join(tab.columns)

    y, x = dmatrices('Weight ~' + features, new_df, return_type='dataframe')

    vif = pd.DataFrame()
    vif['VIF'] = [variance_inflation_factor(x, i) for i in range(x.shape[-1])]
    vif['features'] = x.keys()

    return vif.round(1)

# %%
vif(['Weight'])
# Out:
#     VIF           features
# 0  10.3          Intercept
# 1   1.1              Taxon
# 2   1.0                Sex
# 3   1.0              Month
# 4   1.1                Age
# 5   1.2         Birth_Type
# 6   1.0  Birth_Institution
# 7   1.0        Preg_Status

# %%
x = new_df[['Sex', 'Taxon', 'Month', 'Age', 'Birth_Type', 'Birth_Institution', 'Preg_Status']]
y = new_df['Weight']

model = sm.OLS(y, x, )
l1 = model.fit()

print(l1.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared (uncentered):                   0.606
# Model:                            OLS   Adj. R-squared (uncentered):              0.606
# Method:                 Least Squares   F-statistic:                          1.815e+04
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        19:26:23   Log-Likelihood:                     -7.0588e+05
# No. Observations:               82601   AIC:                                  1.412e+06
# Df Residuals:                   82594   BIC:                                  1.412e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
vif(['Weight', 'Birth_Type'])
# Out:
#     VIF           features
# 0  10.1          Intercept
# 1   1.0              Taxon
# 2   1.0                Sex
# 3   1.0              Month
# 4   1.0                Age
# 5   1.0  Birth_Institution
# 6   1.0        Preg_Status

# %%
x = new_df[['Sex', 'Taxon', 'Month', 'Age', 'Birth_Institution', 'Preg_Status']]
y = new_df['Weight']

model = sm.OLS(y, x)
l2 = model.fit()

print(l2.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared (uncentered):                   0.606
# Model:                            OLS   Adj. R-squared (uncentered):              0.606
# Method:                 Least Squares   F-statistic:                          2.118e+04
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        19:26:23   Log-Likelihood:                     -7.0588e+05
# No. Observations:               82601   AIC:                                  1.412e+06
# Df Residuals:                   82595   BIC:                                  1.412e+06
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
vif(['Weight', 'Birth_Type', 'Age'])
# Out:
#    VIF           features
# 0  9.2          Intercept
# 1  1.0              Taxon
# 2  1.0                Sex
# 3  1.0              Month
# 4  1.0  Birth_Institution
# 5  1.0        Preg_Status

# %%
x = new_df[['Sex', 'Taxon', 'Month', 'Birth_Institution', 'Preg_Status']]
y = new_df['Weight']

model = sm.OLS(y, x)
l3 = model.fit()

print(l3.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared (uncentered):                   0.529
# Model:                            OLS   Adj. R-squared (uncentered):              0.529
# Method:                 Least Squares   F-statistic:                          1.853e+04
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        19:26:23   Log-Likelihood:                     -7.1328e+05
# No. Observations:               82601   AIC:                                  1.427e+06
# Df Residuals:                   82596   BIC:                                  1.427e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
vif(['Weight', 'Birth_Type', 'Age', 'Taxon'])
# Out:
#    VIF           features
# 0  5.8          Intercept
# 1  1.0                Sex
# 2  1.0              Month
# 3  1.0  Birth_Institution
# 4  1.0        Preg_Status

# %%
x = new_df[['Sex', 'Month', 'Birth_Institution', 'Preg_Status']]
y = new_df['Weight']

model = sm.OLS(y, x)
l4 = model.fit()

print(l4.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared (uncentered):                   0.481
# Model:                            OLS   Adj. R-squared (uncentered):              0.481
# Method:                 Least Squares   F-statistic:                          1.911e+04
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        19:26:24   Log-Likelihood:                     -7.1729e+05
# No. Observations:               82601   AIC:                                  1.435e+06
# Df Residuals:                   82597   BIC:                                  1.435e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
vif(['Weight', 'Birth_Type', 'Age', 'Taxon', 'Sex'])
# Out:
#    VIF           features
# 0  4.8          Intercept
# 1  1.0              Month
# 2  1.0  Birth_Institution
# 3  1.0        Preg_Status

# %%
x = new_df[['Month', 'Birth_Institution', 'Preg_Status']]
y = new_df['Weight']

model = sm.OLS(y, x)
l5 = model.fit()

print(l5.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared (uncentered):                   0.461
# Model:                            OLS   Adj. R-squared (uncentered):              0.461
# Method:                 Least Squares   F-statistic:                          2.358e+04
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        19:26:24   Log-Likelihood:                     -7.1880e+05
# No. Observations:               82601   AIC:                                  1.438e+06
# Df Residuals:                   82598   BIC:                                  1.438e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
vif(['Weight', 'Birth_Type', 'Age', 'Taxon', 'Sex', 'Month'])
# Out:
#    VIF           features
# 0  1.2          Intercept
# 1  1.0  Birth_Institution
# 2  1.0        Preg_Status

# %%
x = new_df[['Age', 'Preg_Status']]
y = new_df['Weight']

model = sm.OLS(y, x)
l6 = model.fit()

print(l6.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared (uncentered):                   0.506
# Model:                            OLS   Adj. R-squared (uncentered):              0.506
# Method:                 Least Squares   F-statistic:                          4.236e+04
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        19:26:24   Log-Likelihood:                     -7.1519e+05
# No. Observations:               82601   AIC:                                  1.430e+06
# Df Residuals:                   82599   BIC:                                  1.430e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
ls = [l1, l2, l3, l4, l5, l6]

for i, l in enumerate(ls):
    print(f'l{i + 1}')
    print(f'AIC: {l.aic}')
    print(f'MAPE: {mean_absolute_percentage_error(y, l.predict())}\n')
# Out:
# l1
# AIC: 1411764.087071086
# MAPE: 3.897456304557905
#
# l2
# AIC: 1411762.249315245
# MAPE: 3.896293156249829
#
# l3
# AIC: 1426568.1425571481
# MAPE: 4.959575523814513
#
# l4
# AIC: 1434585.706527537
# MAPE: 4.644430163470652
#
# l5
# AIC: 1437597.9443884618
# MAPE: 4.52391692892082
#
# l6
# AIC: 1430388.1181207993
# MAPE: 1.9683857410184837

# %% [markdown]
# #### Прогноз зависимой переменной по лучшей модели при средних значениях независмых переменных

# %%
data = {
    'Taxon': np.mean(new_df['Taxon']),
    'Sex': np.mean(new_df['Sex']),
    'Month': np.mean(new_df['Month']),
    'Age': np.mean(new_df['Age']),
    'Birth_Type': np.mean(new_df['Birth_Type']),
    'Birth_Institution': np.mean(new_df['Birth_Institution']),
    'Preg_Status': np.mean(new_df['Preg_Status'])
}


mean_df = pd.DataFrame(data, index=[0])
mean_df
# Out:
#        Taxon       Sex     Month       Age  Birth_Type  Birth_Institution  \
# 0  12.569339  0.491265  6.503347  8.499641    0.181196           7.480357
#
#    Preg_Status
# 0     0.023208

# %%
data = {
    # 'Taxon': round(np.mean(new_df['Taxon'])),
    # 'Sex': round(np.mean(new_df['Sex'])),
    # 'Month': round(np.mean(new_df['Month'])),
    'Age': round(np.mean(new_df['Age'])),
    # 'Birth_Type': round(np.mean(new_df['Birth_Type'])),
    # 'Birth_Institution': round(np.mean(new_df['Birth_Institution'])),
    'Preg_Status': round(np.mean(new_df['Preg_Status']))
}


mean_df = pd.DataFrame(data, index=[0])
mean_df
# Out:
#    Age  Preg_Status
# 0    8            0

# %%
pred = new_df.loc[new_df['Taxon'] == 13]
pred = pred.loc[pred['Sex'] == 0]
pred = pred.loc[pred['Month'] == 7]
pred = pred.loc[round(pred['Age']) == 8]
pred = pred.loc[pred['Preg_Status'] == 0]
pred
# Out:
#        Taxon  Sex  Weight  Month   Age  Birth_Type  Birth_Institution  \
# 7283      13    0  1430.0      7  8.10           0                  0
# 7641      13    0   890.0      7  8.28           0                 11
# 7792      13    0   930.0      7  8.27           0                 11
# 8098      13    0  1045.0      7  8.32           0                  0
# 81786     13    0  1053.0      7  8.07           0                  1
# 81878     13    0  1170.0      7  7.95           0                 83
#
#        Preg_Status
# 7283             0
# 7641             0
# 7792             0
# 8098             0
# 81786            0
# 81878            0

# %%
result.predict(mean_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\theba\AppData\Local\Programs\Python\Python311\Lib\site-packages\patsy\compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File c:\Users\theba\AppData\Local\Programs\Python\Python311\Lib\site-packages\patsy\eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'Sex' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# ...

# %% [markdown]
# #### Проверка предпосылок МНК

# %% [markdown]
# ##### Проверка на гомоскедастичность

# %%
from statsmodels.tools.validation import array_like
from scipy import stats

def het_white(resid, exog):
    x = array_like(exog, "exog", ndim=2)
    y = array_like(resid, "resid", ndim=2, shape=(x.shape[0], 1))
    if x.shape[1] < 2:
        raise ValueError("White's heteroskedasticity test requires exog to"
                         "have at least two columns where one is a constant.")
    nobs, nvars0 = x.shape
    i0, i1 = np.triu_indices(nvars0)
    exog = x[:, i0] * x[:, i1]
    nobs, nvars = exog.shape
    assert nvars == nvars0 * (nvars0 - 1) / 2. + nvars0
    resols = sm.OLS(y ** 2, exog).fit()
    fval = resols.fvalue
    fpval = resols.f_pvalue
    lm = nobs * resols.rsquared
    # Note: degrees of freedom for LM test is nvars minus constant
    # degrees of freedom take possible reduced rank in exog into account
    # df_model checks the rank to determine df
    # extra calculation that can be removed:
    # assert resols.df_model == np.linalg.matrix_rank(exog) - 1
    lmpval = stats.chi2.sf(lm, resols.df_model)
    return lm, lmpval, fval, fpval

# %%
white_test = het_white(l2.resid, l2.model.exog)

labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

print(dict(zip(labels, white_test)))

if white_test[1] < 0.05 or white_test[3] < 0.05:
    print('Присутствует гомоскедастичность')
else:
    print('Присутствует гетероскедастичность')
# Out:
# {'Test Statistic': 21485.38221819332, 'Test Statistic p-value': 0.0, 'F-Statistic': 1451.580147070692, 'F-Test p-value': 0.0}
# Присутствует гомоскедастичность

# %% [markdown]
# Остатки

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(l2, 'Age', fig=fig)
# Out:
# eval_env: 1

# %%
plt.figure(figsize=(8,5))
plt.hist(l2.resid_pearson,bins=20,edgecolor='k')
plt.ylabel('Count',fontsize=15)
plt.xlabel('Normalized residuals',fontsize=15)
plt.title("Histogram of normalized residuals",fontsize=18)
plt.show()

# %%
from statsmodels.graphics.gofplots import qqplot

plt.figure(figsize=(8,5))
fig=qqplot(l2.resid_pearson,line='45',fit='True')
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("Theoretical quantiles",fontsize=15)
plt.ylabel("Sample quantiles",fontsize=15)
plt.title("Q-Q plot of normalized residuals",fontsize=18)
plt.grid(True)
plt.show()

# %% [markdown]
# Проверка на нормальность (Шапиро)

# %%
from scipy.stats import shapiro

s, p=shapiro(l2.resid)

if p < 0.05:
    print("Нет нормального распределения")
else:
    print("Нормально распределены")
# Out:
# Нет нормального распределения
# c:\Users\theba\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# Расстояние Кука

# %%
from statsmodels.stats.outliers_influence import OLSInfluence as influence

inf=influence(l2)

(c, p) = inf.cooks_distance
plt.figure(figsize=(8,5))
plt.title("Cook's distance plot for the residuals",fontsize=16)
plt.stem(np.arange(len(c)), c, markerfmt=",")
plt.grid(True)
plt.show()

# %% [markdown]
# Проверка на автокорреляцию

# %%
def dur_wa(resid):
    dw = durbin_watson(resid)
    print(dw)

    if round(dw) == 2:
        print("Автокорреляция отсутствует")
    elif round(dw) > 2:
        print('Присутствует отрицательная автокорреляция')
    elif round(dw) < 2:
        print('Присутствует положительная автокорреляция')

dur_wa(l2.resid)
# Out:
# 0.08213759207376108
# Присутствует положительная автокорреляция

# %%
for i, j in enumerate(ls):
    print(f'l{i + 1}:')
    dur_wa(j.resid)
    print('\n')
# Out:
# l1:
# 0.08210548491102772
# Присутствует положительная автокорреляция
#
#
# l2:
# 0.08213759207376108
# Присутствует положительная автокорреляция
#
#
# l3:
# 0.10340002839918896
# Присутствует положительная автокорреляция
#
#
# l4:
# 0.17582994384647155
# Присутствует положительная автокорреляция
#
#
# l5:
# 0.22248949488289965
# Присутствует положительная автокорреляция
#
#
# l6:
# 0.058112153182850686
# Присутствует положительная автокорреляция
